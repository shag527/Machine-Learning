# %% [markdown]
# # Transfer Learning
# Usind the ResNet50 model, trained on imagenet dataset, in order to quickly classify new images

# %%
# Importing files

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# The ResNet50 pre-trained CNN expects inputs of 224x224 resolution, and will classify objects into one of 1,000 possible categories.

# %%
from IPython.display import Image
Image(filename='fighterjet.jpeg') 
img_path = 'fighterjet.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Loading the model
model=ResNet50(weights='imagenet')
# Out:
# ...
# 102973440/102967424 [==============================] - 90s 1us/step

# %%
pred=model.predict(x)

# %%
print('Predicted:', decode_predictions(pred, top=3)[0])
# Out:
# ...
# 40960/35363 [==================================] - 0s 3us/step
# Predicted: [('n04552348', 'warplane', 0.7799484), ('n03773504', 'missile', 0.12333893), ('n04008634', 'projectile', 0.08219561)]

# %%
def classify(img_path):
    display(Image(filename=img_path))
    
    img = image.load_img(img_path, target_size=(224, 224))

    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
classify('galaxy.jpg')
# Out:
# Predicted: [('n01910747', 'jellyfish', 0.45324746), ('n03065424', 'coil', 0.1421622), ('n09229709', 'bubble', 0.0784197)]

# %%
classify('stairs.jpeg')
# Out:
# Predicted: [('n04033901', 'quill', 0.21566944), ('n03201208', 'dining_table', 0.19942664), ('n04590129', 'window_shade', 0.11029013)]
